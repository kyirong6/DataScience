# %%
import pandas as pd
from scipy import stats as sp
import matplotlib.pyplot as plt

# %%
tweets = pd.read_csv("dog_rates_tweets.csv", sep=',', parse_dates=['created_at'])

# %%
regex = r'(\d+(\.\d+)?)/10'
tweets = tweets[tweets.text.str.contains(regex)]
tweets['rating'] = pd.to_numeric(tweets.text.str.extract(regex)[0], downcast='float')
tweets = tweets[tweets.rating <= 25]
tweets = tweets[tweets.rating >= 0]
# Out:
# /anaconda3/envs/353/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.

# %%
def to_timestamp(x):
    return x.timestamp()

tweets['timestamp'] = tweets['created_at'].apply(to_timestamp)

# %%
lr = sp.linregress(tweets.timestamp, tweets.rating)
tweets['prediction'] = (tweets.timestamp * lr.slope) + lr.intercept

# %%
tweets
# Out:
#                        id          created_at  \
# 2      994363623421153280 2018-05-09 23:48:56
# 7      993889039714578432 2018-05-08 16:23:07
# 8      993629544463642624 2018-05-07 23:11:58
# 24     992198572664860672 2018-05-04 00:25:48
# 30     991744041351090177 2018-05-02 18:19:39
# 35     991399795892916224 2018-05-01 19:31:45
# 41     990987750601093120 2018-04-30 16:14:26
# 50     989657223084244992 2018-04-27 00:07:23
# 55     989300750152069120 2018-04-26 00:30:53
# 59     989176681243070464 2018-04-25 16:17:53
# 60     988932682615853057 2018-04-25 00:08:19
# 62     988573045076963328 2018-04-24 00:19:15
# 65     988455306224128006 2018-04-23 16:31:24
# 66     988208849340510209 2018-04-23 00:12:04
# 75     987398687562371072 2018-04-20 18:32:46
# 77     986762231290490881 2018-04-19 00:23:43
# 79     986639920189108224 2018-04-18 16:17:42
# 80     986394000415485952 2018-04-18 00:00:30
# 83     985700162956865536 2018-04-16 02:03:26
# ...

# %%
lr.slope, lr.intercept
# Out:
# (3.515929974847721e-08, -40.46415517811654)

# %%
plt.figure(figsize=(10, 7))
plt.xticks(rotation=25)
plt.xlabel("Date")
plt.ylabel("Rating")
plt.scatter(tweets.created_at, tweets.rating, color='b', label="original data", alpha=.5)
plt.plot(tweets.created_at, lr.intercept + lr.slope*tweets.timestamp, color='r', label='fitted line', linewidth=3)
plt.legend()
plt.show()
# Out:
# /anaconda3/envs/353/lib/python3.7/site-packages/pandas/plotting/_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)
